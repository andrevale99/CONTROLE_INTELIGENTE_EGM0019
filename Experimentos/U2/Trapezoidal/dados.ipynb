# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
txt = "PI/teste13.txt"

data = np.loadtxt(txt)

tempo = data[:, 0]
sp = data[:, 1]
erro = data[:, 2]
controle = data[:, 3]
omega = data[:, 4]

plt.plot(tempo, sp, label="SetPoint", color="black", linestyle='--')
plt.plot(tempo, omega, label="RPM", color="red", linestyle='-')
# plt.plot(tempo, controle, label="Controle", linestyle='--')

plt.grid()
plt.legend()

plt.show()
