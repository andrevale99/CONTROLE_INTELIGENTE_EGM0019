# %%
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

PATH = os.getcwd()
print(PATH)

print(os.listdir())

TextFile = os.listdir()[0]
# Out:
# /home/andre/Documents/Git/CONTROLE_INTELIGENTE_EGM0019/Experimentos/MalhaAberta
# ['RPM_min.txt', 'experimentos.ipynb', 'teste_02.txt', 'teste_01.txt', 'dados.txt']

# %% [markdown]
# # Cálculos

# %% [markdown]
# $\theta = \frac{EncoderA}{Resolucao} \cdot 360$
#
# $Resolucao = \frac{Encoder}{\theta} \cdot 360$

# %%
# linha 19222 do arquivo teste_02.txt
theta_o = 7611.49

# linha 19223 do arquivo teste_02.txt
theta_f = 7505.98

theta = (np.abs(theta_f-theta_o))


Resolucao =  QtdPulsos / theta * 360

# %% [markdown]
# # Gráficos dos dados

# %%
data = np.loadtxt(TextFile)

plt.plot(data[:,0],data[:,1])

plt.title("Tempo do Cálculo do encoder (Periodo = 100ms)")
plt.ylabel("Tempo do cálculo (us)")
plt.xlabel('s')
plt.grid()

plt.show()

# %%
data = np.loadtxt(TextFile)

print(f'Valor maximo em RPM: {np.max(data[:,6])}')
print(f'Valor maximo em RPM (absoluto): {np.abs(np.min(data[:,6]))}')

plt.plot(data[:,0], data[:,6])

plt.title("Omega (RPM)")
plt.ylabel("RPM")
plt.xlabel('s')
plt.grid()

plt.show()
# Out:
# Valor maximo em RPM: 100.23
# Valor maximo em RPM (absoluto): 112.54

# %%
data = np.loadtxt(TextFile)

plt.plot(data[:,0],data[:,5])

plt.title("Theta (Graus)")
plt.ylabel("Graus")
plt.xlabel('s')
plt.grid()

plt.show()
