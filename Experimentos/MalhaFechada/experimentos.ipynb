# %% [markdown]
# # Valores dos experimentos
#
# 1. [Experimento 1](./teste_01_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.01$;
#     * $K_d = 0.00$;
#     * $T = 100 ms$.
#
# 2. [Experimento 2](./teste_02_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.1$;
#     * $K_d = 0.00$;
#     * $T = 100 ms$.
#
# 3. [Experimento 3](./teste_03_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.1$;
#     * $K_d = 0.00$;
#     * $T = 100 ms$.
#
# 4. [Experimento 4](./teste_04_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.01$;
#     * $K_d = 0.01$;
#     * $T = 100 ms$.
#
# 5. [Experimento 5](./teste_05_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.01$;
#     * $K_d = 0.10$;
#     * $T = 100 ms$.
#
# 6. [Experimento 6](./teste_06_T100ms.txt)
#     * $K_p = 0.5$;
#     * $K_i = 0.1$;
#     * $K_d = 0.10$;
#     * $T = 100 ms$.
#
# 7. [Experimento 7](./teste_07_T100ms.txt)
#     * $K_p = 1$;
#     * $K_i = 0.01$;
#     * $K_d = 0.30$;
#     * $T = 100 ms$.
#
# 8. [Experimento 8](./teste_08_T100ms.txt)
#     * $K_p = 0.8$;
#     * $K_i = 0.0$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 9. [Experimento 9](./teste_09_T100ms.txt)
#     * $K_p = 1.0$;
#     * $K_i = 0.0$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 10. [Experimento 10](./teste_10_T100ms.txt)
#     * $K_p = 1.5$;
#     * $K_i = 0.0$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 11. [Experimento 11](./teste_11_T100ms.txt)
#     * $K_p = 5$;
#     * $K_i = 0.0$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 12. [Experimento 12](./teste_12_T100ms.txt)
#     * $K_p = 1.0$;
#     * $K_i = 0.5$;
#     * $K_d = 0.3$;
#     * $T = 100 ms$.
#
# 13. [Experimento 13](./teste_13_T100ms.txt)
#     * $K_p = 2.0$;
#     * $K_i = 1.3$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 14. [Experimento 14](./teste_14_T100ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 100 ms$.
#
# 15. [Experimento 15](./teste_15_T85ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 85 ms$.
#
# 16. [Experimento 16](./teste_16_T70ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 70 ms$.
#
# 17. [Experimento 17](./teste_17_T55ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 55 ms$.
#
# 18. [Experimento 18](./teste_18_T40ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 40 ms$.
#
# 19. [Experimento 19](./teste_19_T25ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 25 ms$.
#
# 20. [Experimento 20](./teste_20_T10ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 10 ms$.
#
# 21. [Experimento 21](./teste_21_T5ms.txt)
#     * $K_p = 0.3$;
#     * $K_i = 1.0$;
#     * $K_d = 0.0$;
#     * $T = 5 ms$.

# %%
import matplotlib.pyplot as plt
import numpy as np 
import os
import pandas as pd

PATH = os.getcwd()
print(PATH)

print(os.listdir())

TextFile = f"teste_04_T100ms.txt"
print(TextFile)

data = np.loadtxt(TextFile)

tempo = data[:, 0]
tempo_de_calculo = np.mean(data[:,1])
setpoint = data[:,2]
pwm = data[:,3]
qtdPulsosCanalA = data[:,4]
qtdPulsosPorPeriodo = data[:,5]
theta = data[:,6]
omega = data[:,7]
erro = data[:,8]
acaoP = data[:,9]
acaoI = data[:,10]
acaoD = data[:,11]
sinalDeControle = data[:,12]
# Out:
# /home/andre/Documents/Git/CONTROLE_INTELIGENTE_EGM0019/Experimentos/MalhaFechada
# ['teste_10_T100ms.txt', 'teste_09_T100ms.txt', 'teste_17_T55ms.txt', 'teste_05_T100ms.txt', 'teste_14_T100ms.txt', 'teste_21_T5ms.txt', 'teste_11_T100ms.txt', 'teste_20_T10ms.txt', 'teste_04_T100ms.txt', 'teste_02_T100ms.txt', 'TempoxSetpoint.png', 'teste_06_T100ms.txt', 'teste_16_T70ms.txt', 'teste_13_T100ms.txt', 'teste_07_T100ms.txt', 'experimentos.ipynb', 'teste_18_T40ms.txt', 'teste_03_T100ms.txt', 'teste_08_T100ms.txt', 'teste_12_T100ms.txt', 'teste_15_T85ms.txt', 'teste_19_T25ms.txt', 'teste_01_T100ms.txt']
# teste_04_T100ms.txt

# %% [markdown]
# # Disposição das colunas

# %% [markdown]
# **1.** Tempo (s)
#
# **2.** Tempo Total do calculo (us)
#
# **3.** Setpoint
#
# **4.** PWM
#
# **5.** Quantidade de Pulsos do canal A
#
# **6.** Quantidade de Pulsos por Período
#
# **7.** Theta (graus)
#
# **8.** Omega (RPM)
#
# **9.** Erro
#
# **10.** Ação Proporcional
#
# **11.** Ação Integrativa
#
# **12.** Ação Derivativa
#
# **13.** Sinal de Controle

# %%
def plotData(xdata, ylist, labellist=[],title="",xlabel="", ylabel="", saveImg = False, titleImg="Grafico"):
    for i in range(len(ylist)):
        plt.plot(xdata, ylist[i], label=labellist[i])

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid()

    if saveImg == True:
        plt.savefig(PATH + "/" + titleImg + ".png")

    plt.show()

# %% [markdown]
# # Tempo x Setpoint

# %%
plotData(tempo, [setpoint],["setpoint"],
         "Tempo x Setpoint",
         "tempo (s)", "setpoint",
         False, "TempoxSetpoint")

# %% [markdown]
# # Tempo x Omega

# %%
plotData(tempo, [omega], ["omega"],
         "Tempo x Omega",
         "tempo (s)", "Omega (RPM)",
         False, "TempoxOmega")

# %%
plotData(tempo, [omega, setpoint], ["omega", "setpoint"],
         "Tempo x Omega e Setpoint",
         "tempo (s)", "Omega (RPM)",
         False, "TempoxSetpoint")

# %%
plotData(tempo, [acaoP, acaoI, acaoD], ["acaoP", "acaoI", "acaoD"],
         "Tempo x Acoes",
         "tempo (s)", "Sinais",
         False, "TempoxSetpoint")
